# %%
from pthPontos.MyNetwork import getModel
model = getModel(r'pthPontos\dlv3p_rgb_3.pth')

# %%
from dataset.datasetMilho import DatasetMilho
mydata = DatasetMilho()
print(mydata.__len__())
# Out:
# 1184

# %%
model.eval()
image,mask = mydata.__getitem__(5)
print(len(image))
predict = model(image)
print(predict.shape)
# Out:
# 3
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 4
#       2 image,mask = mydata.__getitem__(5)
#       3 print(len(image))
# ----> 4 predict = model(image[0])
#       5 print(predict.shape)
#
# File c:\Users\Angelo\Documents\IC_milho\weedsgalore\venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Angelo\Documents\IC_milho\weedsgalore\venv\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
# ...

# %%
def fatorial(numero):
    if numero == 0 or numero == 1:
        return 1
    return numero * fatorial(numero - 1)
operacoes_por_segundo = 1e9
segundos = fatorial(8*8)/operacoes_por_segundo
minutos = segundos/60
horas = minutos/60
dias = horas/24
meses = dias / 31
anos = meses /12
milenios = anos/1000

print(milenios)
# Out:
# 3.947846107933971e+69
