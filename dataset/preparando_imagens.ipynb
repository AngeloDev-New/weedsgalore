# %%
import os
import cv2
import matplotlib.pyplot as plt
path_images = r'G:\My Drive\data'
# image_paths,image_name = 
print(os.listdir(path_images))
for image_path,image_name in [(os.path.join(path_images,image_name),image_name) for image_name in os.listdir(path_images)]:
    image = cv2.imread(image_path,cv2.IMREAD_COLOR_RGB)
    r,g,b = cv2.split(image)
    cv2.imwrite(f'images/{image_name.replace("image","r_image")}',r)
    cv2.imwrite(f'images/{image_name.replace("image","g_image")}',g)
    cv2.imwrite(f'images/{image_name.replace("image","b_image")}',b)
# Out:
# ['91_image.png', '4_image.png', '105_image.png', '92_image.png', '61_image.png', '3_image.png', '1316_image.png', '46_image.png', '121_image.png', '122_image.png', '107_image.png', '60_image.png', '17_image.png', '47_image.png', '1_image.png', '75_image.png', '106_image.png', '16_image.png', '15_image.png', '120_image.png', '5_image.png', '30_image.png', '62_image.png', '45_image.png', '2_image.png', '31_image.png', '90_image.png', '76_image.png', '14_image.png', '102_image.png', '101_image.png', '100_image.png', '99_image.png', '218_image.png', '217_image.png', '216_image.png', '57_image.png', '58_image.png', '56_image.png', '84_image.png', '83_image.png', '82_image.png', '81_image.png', '27_image.png', '26_image.png', '25_image.png', '24_image.png', '200_image.png', '185_image.png', '125_image.png', '155_image.png', '116_image.png', '115_image.png', '114_image.png', '40_image.png', '39_image.png', '38_image.png', '69_image.png', '68_image.png', '67_image.png', '66_image.png', '215_
# ...

# %%
import os
images_path = [path for path in os.listdir('../images') if path.endswith('png')]
out_path = 'data/semantics'
print(images)
# Out:
# ['1000_image.png', '1001_image.png', '1002_image.png', '1003_image.png', '1004_image.png', '1005_image.png', '1006_image.png', '1007_image.png', '1008_image.png', '1009_image.png', '100_image.png', '1010_image.png', '1011_image.png', '1012_image.png', '1013_image.png', '1014_image.png', '1015_image.png', '1016_image.png', '1017_image.png', '1018_image.png', '1019_image.png', '101_image.png', '1020_image.png', '1021_image.png', '1022_image.png', '1023_image.png', '1024_image.png', '1025_image.png', '1026_image.png', '1027_image.png', '1028_image.png', '1029_image.png', '102_image.png', '1030_image.png', '1031_image.png', '1032_image.png', '1033_image.png', '1034_image.png', '1035_image.png', '1036_image.png', '1037_image.png', '1038_image.png', '1039_image.png', '103_image.png', '1040_image.png', '1041_image.png', '1042_image.png', '1043_image.png', '1044_image.png', '1045_image.png', '1046_image.png', '1047_image.png', '1048_image.png', '1049_image.png', '104_image.png', '1050_image.
# ...
