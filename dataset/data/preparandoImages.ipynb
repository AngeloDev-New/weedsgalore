# %% [markdown]
# # rgb...

# %%
import os cv2

# %%
imgsNames = os.listdir('images')

for in_image, out_img_r, out_img_g, out_img_b in [
    (os.path.join('images', image),
     os.path.join('images2', image.replace('_', '_r_')),
     os.path.join('images2', image.replace('_', '_g_')),
     os.path.join('images2', image.replace('_', '_b_')))
    for image in imgsNames
]:
    imagem = cv2.imread(in_image,cv2.)
    print(in_image, out_img_r, out_img_g, out_img_b)  # Apenas para verificar os resultados
# Out:
# images\0_image.png images2\0_r_image.png images2\0_g_image.png images2\0_b_image.png
# images\10_image.png images2\10_r_image.png images2\10_g_image.png images2\10_b_image.png
# images\11_image.png images2\11_r_image.png images2\11_g_image.png images2\11_b_image.png
# images\12_image.png images2\12_r_image.png images2\12_g_image.png images2\12_b_image.png
# images\13_image.png images2\13_r_image.png images2\13_g_image.png images2\13_b_image.png
# images\14_image.png images2\14_r_image.png images2\14_g_image.png images2\14_b_image.png
# images\15_image.png images2\15_r_image.png images2\15_g_image.png images2\15_b_image.png
# images\16_image.png images2\16_r_image.png images2\16_g_image.png images2\16_b_image.png
# images\17_image.png images2\17_r_image.png images2\17_g_image.png images2\17_b_image.png
# images\18_image.png images2\18_r_image.png images2\18_g_image.png images2\18_b_image.png
# images\19_image.png images2\19_r_image.png images2\19_g_image.png images2\19_b_image.png
# ...
